# %%
import sys
print(sys.version)
# Out:
# 3.6.3 (default, Oct  3 2017, 21:45:48)
# [GCC 7.2.0]

# %%
import pandas as pd

# %% [markdown]
# ### Meteology Data

# %%
bj_meo = pd.read_csv('beijing_17_18_meo.csv')
bj_meo.head()
# Out:
#    station_id   longitude   latitude             utc_time  temperature  \
# 0  shunyi_meo  116.615278  40.126667  2017-01-30 16:00:00         -1.7
# 1  shunyi_meo  116.615278  40.126667  2017-01-30 17:00:00         -3.5
# 2  shunyi_meo  116.615278  40.126667  2017-01-30 18:00:00         -3.7
# 3  shunyi_meo  116.615278  40.126667  2017-01-30 19:00:00         -3.9
# 4  shunyi_meo  116.615278  40.126667  2017-01-30 20:00:00         -4.1
#
#    pressure  humidity  wind_direction  wind_speed      weather
# 0    1028.7        15           215.0         1.6  Sunny/clear
# 1    1028.4        24            16.0         1.0         Haze
# 2    1028.1        27            32.0         1.1         Haze
# 3    1027.6        27            21.0         0.9         Haze
# 4    1026.7        26            17.0         1.1         Haze

# %%
bj_meo.station_id.unique()
# Out:
# array(['shunyi_meo', 'hadian_meo', 'yanqing_meo', 'miyun_meo',
#        'huairou_meo', 'shangdianzi_meo', 'pinggu_meo', 'tongzhou_meo',
#        'chaoyang_meo', 'pingchang_meo', 'zhaitang_meo', 'mentougou_meo',
#        'beijing_meo', 'shijingshan_meo', 'fengtai_meo', 'daxing_meo',
#        'fangshan_meo', 'xiayunling_meo'], dtype=object)

# %% [markdown]
# ### Grid Weather Data

# %%
bj_grid = pd.read_csv('Beijing_historical_meo_grid.csv')
bj_grid.head(20)
# Out:
#          stationName  longitude  latitude             utc_time  temperature  \
# 0   beijing_grid_000      115.0      39.0  2017-01-01 00:00:00        -5.47
# 1   beijing_grid_001      115.0      39.1  2017-01-01 00:00:00        -5.53
# 2   beijing_grid_002      115.0      39.2  2017-01-01 00:00:00        -5.70
# 3   beijing_grid_003      115.0      39.3  2017-01-01 00:00:00        -5.88
# 4   beijing_grid_004      115.0      39.4  2017-01-01 00:00:00        -5.34
# 5   beijing_grid_005      115.0      39.5  2017-01-01 00:00:00        -4.81
# 6   beijing_grid_006      115.0      39.6  2017-01-01 00:00:00        -4.98
# 7   beijing_grid_007      115.0      39.7  2017-01-01 00:00:00        -5.49
# 8   beijing_grid_008      115.0      39.8  2017-01-01 00:00:00        -6.17
# 9   beijing_grid_009      115.0      39.9  2017-01-01 00:00:00        -7.17
# 10  beijing_grid_010      115.0      40.0  2017-01-01 00:00:00        -8.17
# ...

# %%
bj_grid[(bj_grid.longitude == 115.0) & (bj_grid.latitude == 39.0)].head()
# Out:
#            stationName  longitude  latitude             utc_time  temperature  \
# 0     beijing_grid_000      115.0      39.0  2017-01-01 00:00:00        -5.47
# 651   beijing_grid_000      115.0      39.0  2017-01-01 01:00:00        -2.69
# 1302  beijing_grid_000      115.0      39.0  2017-01-01 02:00:00         0.08
# 1953  beijing_grid_000      115.0      39.0  2017-01-01 03:00:00         2.86
# 2604  beijing_grid_000      115.0      39.0  2017-01-01 04:00:00         3.74
#
#       pressure  humidity  wind_direction  wind_speed/kph
# 0       984.73     76.60           53.71            3.53
# 651     984.75     63.63           69.33            3.50
# 1302    984.78     50.67           84.09            3.73
# 1953    984.80     37.70           96.45            4.17
# 2604    984.20     35.93          108.24            4.49

# %% [markdown]
# ### Beijing Station Data

# %%
bj_stations = pd.read_csv('beijing_stations.csv')
bj_stations.head()
# Out:
#           stationId  longitude  latitude stationType
# 0         dongsi_aq    116.417    39.929       Urban
# 1        tiantan_aq    116.407    39.886       Urban
# 2       guanyuan_aq    116.339    39.929       Urban
# 3  wanshouxigong_aq    116.352    39.878       Urban
# 4   aotizhongxin_aq    116.397    39.982       Urban

# %% [markdown]
# ### Air Quality (target)

# %%
bj_aq = pd.read_csv('beijing_17_18_aq.csv')
bj_aq.head()
# Out:
#          stationId             utc_time  PM2.5   PM10    NO2   CO   O3  SO2
# 0  aotizhongxin_aq  2017-01-01 14:00:00  453.0  467.0  156.0  7.2  3.0  9.0
# 1  aotizhongxin_aq  2017-01-01 15:00:00  417.0  443.0  143.0  6.8  2.0  8.0
# 2  aotizhongxin_aq  2017-01-01 16:00:00  395.0  467.0  141.0  6.9  3.0  8.0
# 3  aotizhongxin_aq  2017-01-01 17:00:00  420.0  484.0  139.0  7.4  3.0  9.0
# 4  aotizhongxin_aq  2017-01-01 18:00:00  453.0  520.0  157.0  7.6  4.0  9.0

# %%
bj_target = pd.merge(bj_aq, bj_stations, on='stationId')
bj_target.head()
# Out:
#          stationId             utc_time  PM2.5   PM10    NO2   CO   O3  SO2  \
# 0  aotizhongxin_aq  2017-01-01 14:00:00  453.0  467.0  156.0  7.2  3.0  9.0
# 1  aotizhongxin_aq  2017-01-01 15:00:00  417.0  443.0  143.0  6.8  2.0  8.0
# 2  aotizhongxin_aq  2017-01-01 16:00:00  395.0  467.0  141.0  6.9  3.0  8.0
# 3  aotizhongxin_aq  2017-01-01 17:00:00  420.0  484.0  139.0  7.4  3.0  9.0
# 4  aotizhongxin_aq  2017-01-01 18:00:00  453.0  520.0  157.0  7.6  4.0  9.0
#
#    longitude  latitude stationType
# 0    116.397    39.982       Urban
# 1    116.397    39.982       Urban
# 2    116.397    39.982       Urban
# 3    116.397    39.982       Urban
# 4    116.397    39.982       Urban

# %%
bj_aq.stationId.unique()
# Out:
# array(['aotizhongxin_aq', 'badaling_aq', 'beibuxinqu_aq', 'daxing_aq',
#        'dingling_aq', 'donggaocun_aq', 'dongsi_aq', 'dongsihuan_aq',
#        'fangshan_aq', 'fengtaihuayuan_aq', 'guanyuan_aq', 'gucheng_aq',
#        'huairou_aq', 'liulihe_aq', 'mentougou_aq', 'miyun_aq',
#        'miyunshuiku_aq', 'nansanhuan_aq', 'nongzhanguan_aq',
#        'pingchang_aq', 'pinggu_aq', 'qianmen_aq', 'shunyi_aq',
#        'tiantan_aq', 'tongzhou_aq', 'wanliu_aq', 'wanshouxigong_aq',
#        'xizhimenbei_aq', 'yanqin_aq', 'yizhuang_aq', 'yongdingmennei_aq',
#        'yongledian_aq', 'yufa_aq', 'yungang_aq', 'zhiwuyuan_aq'],
#       dtype=object)

# %% [markdown]
# ### Research a certain area, say AoTiZhongXin

# %%
urban = bj_target[bj_target.stationType=='Urban'].dropna()

# %%
import seaborn as sns

# %%
sns.distplot(urban['PM2.5'])
# Out:
# /home/inq/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(bj_target[bj_target.stationId=='badaling_aq']['PM2.5'].dropna())
# Out:
# /home/inq/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df = bj_target[bj_target.stationId=='aotizhongxin_aq']
g = sns.lmplot(x="longitude", y="latitude", hue="PM2.5", data=df)

# %%
bj_mean = bj_target.groupby('stationId').mean()

# %% [markdown]
# ## Use mean value to make predictions

# %%
row_index =

# %% [markdown]
# ## Export answer to .csv

# %%
bj_mean.head()
# Out:
#                      PM2.5        PM10        NO2        CO         O3  \
# stationId
# aotizhongxin_aq  55.480055   81.646714  51.735557  0.903821  58.853100
# badaling_aq      45.278841   85.325442  45.355482  0.651071  53.960344
# beibuxinqu_aq    57.399474   95.082727  43.338018  1.059149  51.130678
# daxing_aq        61.566671  107.165350  51.170319  0.981474  55.665430
# dingling_aq      45.829620   64.416765  25.405026  0.716406  68.948980
#
#                       SO2  longitude  latitude
# stationId
# aotizhongxin_aq  8.724759    116.397    39.982
# badaling_aq      8.172845    115.988    40.365
# beibuxinqu_aq    5.352282    116.174    40.090
# daxing_aq        9.789060    116.404    39.718
# dingling_aq      6.355019    116.220    40.292

# %%
ans = pd.read_csv('sample_submission.csv', index_col=0)
ans.head()
# Out:
#              PM2.5  PM10  O3
# test_id
# dongsi_aq#0      0     0   0
# dongsi_aq#1      0     0   0
# dongsi_aq#2      0     0   0
# dongsi_aq#3      0     0   0
# dongsi_aq#4      0     0   0

# %%
for index, row in ans.iterrows():
    station = index.split("#")[0]
    # row['PM2.5']=10
    if station in bj_mean.index:
        ans.loc[index] = bj_mean.loc[station, ['PM2.5', 'PM10', 'O3']]

# %%
ans.to_csv('test_submission.csv')
